# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sys
import os
import math
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf
import scipy.integrate as integrate
import random
import h5py
from scipy.optimize import fsolve
from scipy.optimize import bisect

plt.rc('text',usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{bm}')
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Computer Modern'
plt.rcParams['axes.linewidth']  = 3.0
plt.rcParams['axes.labelsize']  = 30
plt.rcParams.update({'font.size': 22})
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['xtick.major.size'] = 4
plt.rcParams['ytick.major.size'] = 4
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['legend.fontsize']  = 22
plt.rcParams['legend.frameon']  = True
plt.rcParams["legend.fancybox"] = True
plt.rcParams["legend.shadow"] = True
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["axes.facecolor"] = 'white'
plt.rcParams["axes.edgecolor"] = 'black'

plt.rcParams['figure.figsize'] = 8, 8

plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 0
plt.rcParams['ytick.minor.width'] = 0

################################################

e=0.5
h=5.4
nu=0
beta_low=0.2245
beta_high=0.2265

###############################################


color=iter(plt.cm.rainbow(np.linspace(0,1,6)))

HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s/Test" %(e, nu))

L=np.array([8, 10])

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10,10))
fig.suptitle(r"$\nu=%d$" %nu)
ax1[0].set_ylabel(r"$U$")
ax2[0].set_ylabel(r"$L \Upsilon$")
ax1[1].set_ylabel(r"$L \rho$")
ax2[1].set_ylabel(r"$|\Psi_0|$")
ax2[1].set_xlabel(r"$\beta$")
ax1[0].set_yscale('linear')
ax2[0].set_yscale('linear')
ax2[0].set_xlabel(r"$\beta$")
ax1[0].set_xlim((beta_low, beta_high))
ax2[0].set_xlim((beta_low, beta_high))
ax1[0].grid()
ax2[0].grid()

for l in range(len(L)):
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(HOMEDIR, L[l], e,  h, nu, beta_low, beta_high))
    file_Js_sum=("%s/Helicity_modulus_sum.txt" %(BASEDIR))
    beta, Js_sum, Js_sum_err= np.loadtxt(file_Js_sum, usecols=(0,1,2), unpack=True)
    
    file_Binder=("%s/Binder_cumulant.txt" %(BASEDIR))
    data_U= np.loadtxt(file_Binder)
    beta=data_U[0,:]
    U=data_U[1,:]
    U_err=data_U[2,:]

    file_DS=("%s/Dual_Stiffness.txt" %(BASEDIR))
    data_DS= np.loadtxt(file_DS)
    beta=data_DS[0,:]
    DS=data_DS[1,:]
    DS_err=data_DS[2,:]
    
    file_Psi=("%s/Psi_Density.txt" %(BASEDIR))
    data_Psi= np.loadtxt(file_Psi)
    print(data_Psi[3,:])
    beta=data_Psi[0,:]
    Psi1=data_Psi[1,:]
    Psi1_err=data_Psi[2,:]
    Psi2=data_Psi[3,:]
    Psi2_err=data_Psi[4,:]   
    Psi2=data_Psi[5,:]
    Psi2_err=data_Psi[6,:]  
    
    ax1[0].errorbar(beta, U, yerr=U_err, fmt='o-', label="%d" %L[l])
    ax2[0].errorbar(beta, L[l]*Js_sum, yerr=L[l]*Js_sum_err, fmt='o-')
    ax1[1].errorbar(beta, L[l]*DS, yerr=L[l]*DS_err, fmt='o-')
    ax2[1].errorbar(beta, Psi1, yerr=Psi1_err, fmt='o-')
    
    #ax1.legend(title="L", loc='best')
    lines = []
    labels = []
    for ax in fig.axes:
        axLine, axLabel = ax.get_legend_handles_labels()
        lines.extend(axLine)
        labels.extend(axLabel)

fig.tight_layout()
fig.subplots_adjust(bottom=0.2, top=0.92)
fig.legend(lines, labels, loc = 'lower center', title="L", ncol=len(L))    
fig.savefig("%s/Critical_points_bmin%s_bmax%s.png" %(HOMEDIR, beta_low, beta_high))
plt.show()
# Out:
# [0.41574812 0.41591003 0.4160313  0.41626831 0.41647204 0.41660821
#  0.41685872 0.41710616 0.41727633 0.41747386 0.41769681 0.41803342
#  0.41823712 0.41846465 0.41872672 0.41898893 0.41925561 0.41957764
#  0.41991176 0.42022422 0.42051724 0.42080472 0.42117187 0.42147508
#  0.42180424 0.42210544 0.42246233 0.42281915 0.42314413 0.42351852
#  0.42385031 0.42419218]
# [0.41434773 0.41445465 0.41461779 0.41478543 0.41491346 0.41507617
#  0.41525841 0.4154192  0.41558205 0.41583481 0.41600011 0.41617962
#  0.41640122 0.41662848 0.41691531 0.41716249 0.41747267 0.41771538
#  0.41807801 0.41838245 0.4186399  0.4190235  0.41941063 0.41966354
#  0.4199935  0.42040662 0.42075753 0.42109881 0.42142098 0.42184756
#  0.42232466 0.42271952]

# %%
################################################

e=0.5
h=5.4
nu=0.1
beta_low=0.2165
beta_high=0.2195

###############################################


color=iter(plt.cm.rainbow(np.linspace(0,1,6)))

HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s" %(e, nu))

L=np.array([8, 10, 12])

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10,10))
fig.suptitle(r"$\nu=%s$" %nu)
ax1[0].set_ylabel(r"$U$")
ax2[0].set_ylabel(r"$L \Upsilon$")
ax1[1].set_ylabel(r"$L \rho$")
ax2[1].set_ylabel(r"$|\Psi_0|$")
ax2[1].set_xlabel(r"$\beta$")
ax1[0].set_yscale('linear')
ax2[0].set_yscale('linear')
ax2[0].set_xlabel(r"$\beta$")
ax1[0].set_xlim((beta_low, beta_high))
ax2[0].set_xlim((beta_low, beta_high))
ax1[0].grid()
ax2[0].grid()

for l in range(len(L)):
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(HOMEDIR, L[l], e,  h, nu, beta_low, beta_high))
    file_Js_sum=("%s/Helicity_modulus_sum.txt" %(BASEDIR))
    beta, Js_sum, Js_sum_err= np.loadtxt(file_Js_sum, usecols=(0,1,2), unpack=True)

    Js_sum=L[l]*Js_sum
    
    file_Binder=("%s/Binder_cumulant.txt" %(BASEDIR))
    data_U= np.loadtxt(file_Binder)
    beta=data_U[0,:]
    U=data_U[1,:]
    U_err=data_U[2,:]

    file_DS=("%s/Dual_Stiffness.txt" %(BASEDIR))
    data_DS= np.loadtxt(file_DS)
    beta=data_DS[0,:]
    DS=data_DS[1,:]
    DS_err=data_DS[2,:]
    
    file_Psi=("%s/Psi_Density.txt" %(BASEDIR))
    data_Psi= np.loadtxt(file_Psi)
    print(data_Psi[3,:])
    beta=data_Psi[0,:]
    Psi1=data_Psi[1,:]
    Psi1_err=data_Psi[2,:]
    Psi2=data_Psi[3,:]
    Psi2_err=data_Psi[4,:]   
    Psi2=data_Psi[5,:]
    Psi2_err=data_Psi[6,:]  
    
    ax1[0].errorbar(beta, U, yerr=U_err, fmt='o-', label="%d" %L[l])
    ax2[0].errorbar(beta, Js_sum, yerr=Js_sum_err, fmt='o-')
    ax1[1].errorbar(beta, L[l]*DS, yerr=L[l]*DS_err, fmt='o-')
    ax2[1].errorbar(beta, Psi1, yerr=Psi1_err, fmt='o-')
    
    #ax1.legend(title="L", loc='best')
    lines = []
    labels = []
    for ax in fig.axes:
        axLine, axLabel = ax.get_legend_handles_labels()
        lines.extend(axLine)
        labels.extend(axLabel)

fig.tight_layout()
fig.subplots_adjust(bottom=0.2, top=0.92)
fig.legend(lines, labels, loc = 'lower center', title="L", ncol=len(L))    
fig.savefig("%s/Critical_points_bmin%s_bmax%s.png" %(HOMEDIR, beta_low, beta_high))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c33cd1d9947b> in <module>
#      10
#      11
# ---> 12 color=iter(plt.cm.rainbow(np.linspace(0,1,6)))
#      13
#      14 HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s" %(e, nu))
#
# NameError: name 'plt' is not defined

# %%
################################################

e=0.5
h=5.4
nu=0.1
beta_low=0.2195
beta_high=0.2215

###############################################


color=iter(plt.cm.rainbow(np.linspace(0,1,6)))

HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s" %(e, nu))

L=np.array([8, 10])

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10,10))
fig.suptitle(r"$\nu=%s$" %nu)
ax1[0].set_ylabel(r"$U$")
ax2[0].set_ylabel(r"$L \Upsilon$")
ax1[1].set_ylabel(r"$L \rho$")
ax2[1].set_ylabel(r"$|\Psi_0|$")
ax2[1].set_xlabel(r"$\beta$")
ax1[0].set_yscale('linear')
ax2[0].set_yscale('linear')
ax2[0].set_xlabel(r"$\beta$")
ax1[0].set_xlim((beta_low, beta_high))
ax2[0].set_xlim((beta_low, beta_high))
ax1[0].grid()
ax2[0].grid()

for l in range(len(L)):
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(HOMEDIR, L[l], e,  h, nu, beta_low, beta_high))
    file_Js_sum=("%s/Helicity_modulus_sum.txt" %(BASEDIR))
    beta, Js_sum, Js_sum_err= np.loadtxt(file_Js_sum, usecols=(0,1,2), unpack=True)

    Js_sum=L[l]*Js_sum
    
    file_Binder=("%s/Binder_cumulant.txt" %(BASEDIR))
    data_U= np.loadtxt(file_Binder)
    beta=data_U[0,:]
    U=data_U[1,:]
    U_err=data_U[2,:]

    file_DS=("%s/Dual_Stiffness.txt" %(BASEDIR))
    data_DS= np.loadtxt(file_DS)
    beta=data_DS[0,:]
    DS=data_DS[1,:]
    DS_err=data_DS[2,:]
    
    file_Psi=("%s/Psi_Density.txt" %(BASEDIR))
    data_Psi= np.loadtxt(file_Psi)
    print(data_Psi[3,:])
    beta=data_Psi[0,:]
    Psi1=data_Psi[1,:]
    Psi1_err=data_Psi[2,:]
    Psi2=data_Psi[3,:]
    Psi2_err=data_Psi[4,:]   
    Psi2=data_Psi[5,:]
    Psi2_err=data_Psi[6,:]  
    
    ax1[0].errorbar(beta, U, yerr=U_err, fmt='o-', label="%d" %L[l])
    ax2[0].errorbar(beta, Js_sum, yerr=Js_sum_err, fmt='o-')
    ax1[1].errorbar(beta, DS, yerr=DS_err, fmt='o-')
    ax2[1].errorbar(beta, Psi1, yerr=Psi1_err, fmt='o-')
    
    #ax1.legend(title="L", loc='best')
    lines = []
    labels = []
    for ax in fig.axes:
        axLine, axLabel = ax.get_legend_handles_labels()
        lines.extend(axLine)
        labels.extend(axLabel)

fig.tight_layout()
fig.subplots_adjust(bottom=0.2, top=0.92)
fig.legend(lines, labels, loc = 'lower center', title="L", ncol=len(L))    
fig.savefig("%s/Critical_points_bmin%s_bmax%s.png" %(HOMEDIR, beta_low, beta_high))
plt.show()
# Out:
# [0.41877283 0.41901749 0.41931103 0.41964237 0.41988387 0.42017369
#  0.42045131 0.42072833 0.42103137 0.42126845 0.42160776 0.42193277
#  0.42222817 0.42246113 0.42273571 0.42307309 0.42333574 0.42364187
#  0.42386564 0.42407875 0.42433885 0.42463524 0.42480151 0.42508209
#  0.42528322 0.42553154 0.42576648 0.42598344 0.42617046 0.42641424
#  0.42666561 0.42686606]
# [0.41786763 0.41813969 0.41840489 0.41863638 0.41894825 0.41924675
#  0.41947864 0.41978288 0.42016996 0.42045146 0.42075795 0.42099971
#  0.42133701 0.42158937 0.42190583 0.42223941 0.42257817 0.42287681
#  0.42312793 0.42347744 0.42373872 0.42393079 0.42415617 0.42449541
#  0.42472249 0.42501295 0.42528542 0.42549994 0.42579575 0.42600395
#  0.42622058 0.42644963]
