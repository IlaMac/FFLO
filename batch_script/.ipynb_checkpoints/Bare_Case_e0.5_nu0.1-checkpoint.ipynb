# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sys
import os
import math
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf
import scipy.integrate as integrate
import random
import h5py
from scipy.optimize import fsolve
from scipy.optimize import bisect

plt.rc('text',usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{bm}')
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Computer Modern'
plt.rcParams['axes.linewidth']  = 3.0
plt.rcParams['axes.labelsize']  = 30
plt.rcParams.update({'font.size': 22})
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['xtick.major.size'] = 4
plt.rcParams['ytick.major.size'] = 4
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['legend.fontsize']  = 22
plt.rcParams['legend.frameon']  = True
plt.rcParams["legend.fancybox"] = True
plt.rcParams["legend.shadow"] = True
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["axes.facecolor"] = 'white'
plt.rcParams["axes.edgecolor"] = 'black'

plt.rcParams['figure.figsize'] = 8, 8

plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 0
plt.rcParams['ytick.minor.width'] = 0

################################################

e=0.5
h=5.4
nu=0.1
beta_low=0.2165
beta_high=0.2195

###############################################


color=iter(plt.cm.rainbow(np.linspace(0,1,6)))

HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s" %(e, nu))

L=np.array([8, 10, 12])

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10,10))
fig.suptitle(r"$\nu=%s$" %nu)
ax1[0].set_ylabel(r"$U$")
ax2[0].set_ylabel(r"$L \Upsilon$")
ax1[1].set_ylabel(r"$L \rho$")
ax2[1].set_ylabel(r"$|\Psi_0|$")
ax2[1].set_xlabel(r"$\beta$")
ax1[0].set_yscale('linear')
ax2[0].set_yscale('linear')
ax2[0].set_xlabel(r"$\beta$")
ax1[0].set_xlim((beta_low, beta_high))
ax2[0].set_xlim((beta_low, beta_high))
ax1[0].grid()
ax2[0].grid()

for l in range(len(L)):
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(HOMEDIR, L[l], e,  h, nu, beta_low, beta_high))
    file_Js_sum=("%s/Helicity_modulus_sum.txt" %(BASEDIR))
    beta, Js_sum, Js_sum_err= np.loadtxt(file_Js_sum, usecols=(0,1,2), unpack=True)
    
    file_Binder=("%s/Binder_cumulant.txt" %(BASEDIR))
    data_U= np.loadtxt(file_Binder)
    beta=data_U[0,:]
    U=data_U[1,:]
    U_err=data_U[2,:]

    file_DS=("%s/Dual_Stiffness.txt" %(BASEDIR))
    data_DS= np.loadtxt(file_DS)
    beta=data_DS[0,:]
    DS=data_DS[1,:]
    DS_err=data_DS[2,:]
    
    file_Psi=("%s/Psi_Density.txt" %(BASEDIR))
    data_Psi= np.loadtxt(file_Psi)
    print(data_Psi[3,:])
    beta=data_Psi[0,:]
    Psi1=data_Psi[1,:]
    Psi1_err=data_Psi[2,:]
    Psi2=data_Psi[3,:]
    Psi2_err=data_Psi[4,:]   
    Psi2=data_Psi[5,:]
    Psi2_err=data_Psi[6,:]  
    
    ax1[0].errorbar(beta, U, yerr=U_err, fmt='o-', label="%d" %L[l])
    ax2[0].errorbar(beta, L[l]*Js_sum, yerr=L[l]*Js_sum_err, fmt='o-')
    ax1[1].errorbar(beta, L[l]*DS, yerr=L[l]*DS_err, fmt='o-')
    ax2[1].errorbar(beta, Psi1, yerr=Psi1_err, fmt='o-')
    
    #ax1.legend(title="L", loc='best')
    lines = []
    labels = []
    for ax in fig.axes:
        axLine, axLabel = ax.get_legend_handles_labels()
        lines.extend(axLine)
        labels.extend(axLabel)

fig.tight_layout()
fig.subplots_adjust(bottom=0.2, top=0.92)
fig.legend(lines, labels, loc = 'lower center', title="L", ncol=len(L))    
fig.savefig("%s/Critical_points_bmin%s_bmax%s.png" %(HOMEDIR, beta_low, beta_high))
plt.show()
# Out:
# [3.14122061 3.15421764 3.16682577 3.17752476 3.19021158 3.20099731
#  3.21643694 3.23135672 3.24888844 3.264777   3.28143994 3.29985696
#  3.31856112 3.33722324 3.3565131  3.37633308 3.39736308 3.42331851
#  3.4431769  3.46525245 3.48447189 3.50480653 3.53049845 3.55416269
#  3.57350501 3.59852019 3.62641193 3.65411917 3.68134714 3.70595423
#  3.73329919 3.75874837]
# [6.01265031 6.03627215 6.05814415 6.08108722 6.10464166 6.1298067
#  6.15483197 6.18387111 6.21460594 6.24269835 6.27740242 6.30988504
#  6.34563248 6.38498859 6.42708111 6.47148419 6.50784635 6.54790864
#  6.58908211 6.63267696 6.67826125 6.72197322 6.7691394  6.81946862
#  6.86586818 6.91684915 6.96412519 7.01380323 7.06525604 7.11926925
#  7.16909284 7.21753541]
# [0.40720215 0.4073493  0.40754297 0.40775596 0.40793621 0.40812904
#  0.40836885 0.40859512 0.40885481 0.40911521 0.40938444 0.40965739
#  0.40996424 0.41027276 0.41061407 0.4109611  0.41134603 0.41174245
#  0.41210832 0.41255442 0.41298283 0.41340076 0.41376983 0.41415808
#  0.41455465 0.414993   0.41541819 0.4158     0.4161971  0.41661274
#  0.41701109 0.4174071 ]

# %%
################################################

e=0.5
h=5.4
nu=0.1
beta_low=0.222
beta_high=0.225

###############################################


color=iter(plt.cm.rainbow(np.linspace(0,1,6)))

HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s" %(e, nu))

L=np.array([8, 10, 12])

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10,10))
fig.suptitle(r"$\nu=%s$" %nu)
ax1[0].set_ylabel(r"$U$")
ax2[0].set_ylabel(r"$L \Upsilon$")
ax1[1].set_ylabel(r"$L \rho$")
ax2[1].set_ylabel(r"$|\Psi_0|$")
ax2[1].set_xlabel(r"$\beta$")
ax1[0].set_yscale('linear')
ax2[0].set_yscale('linear')
ax2[0].set_xlabel(r"$\beta$")

ax1[0].grid()
ax2[0].grid()

for l in range(len(L)):
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(HOMEDIR, L[l], e,  h, nu, beta_low, beta_high))
    file_Js_sum=("%s/Helicity_modulus_sum.txt" %(BASEDIR))
    beta, Js_sum, Js_sum_err= np.loadtxt(file_Js_sum, usecols=(0,1,2), unpack=True)
    
    file_Binder=("%s/Binder_cumulant.txt" %(BASEDIR))
    data_U= np.loadtxt(file_Binder)
    beta=data_U[0,:]
    U=data_U[1,:]
    U_err=data_U[2,:]

    file_DS=("%s/Dual_Stiffness.txt" %(BASEDIR))
    data_DS= np.loadtxt(file_DS)
    beta=data_DS[0,:]
    DS=data_DS[1,:]
    DS_err=data_DS[2,:]
    
    file_Psi=("%s/Psi_Density.txt" %(BASEDIR))
    data_Psi= np.loadtxt(file_Psi)
    print(data_Psi[3,:])
    beta=data_Psi[0,:]
    Psi1=data_Psi[1,:]
    Psi1_err=data_Psi[2,:]
    Psi2=data_Psi[3,:]
    Psi2_err=data_Psi[4,:]   
    Psi2=data_Psi[5,:]
    Psi2_err=data_Psi[6,:]  
    
    ax1[0].errorbar(beta, U, yerr=U_err, fmt='o-', label="%d" %L[l])
    ax2[0].errorbar(beta, L[l]*Js_sum, yerr=Js_sum_err, fmt='o-')
    ax1[1].errorbar(beta, L[l]*DS, yerr=L[l]*DS_err, fmt='o-')
    ax2[1].errorbar(beta, Psi1, yerr=Psi1_err, fmt='o-')
    
    #ax1.legend(title="L", loc='best')
    lines = []
    labels = []
    for ax in fig.axes:
        axLine, axLabel = ax.get_legend_handles_labels()
        lines.extend(axLine)
        labels.extend(axLabel)

fig.tight_layout()
fig.subplots_adjust(bottom=0.2, top=0.92)
fig.legend(lines, labels, loc = 'lower center', title="L", ncol=len(L))    
fig.savefig("%s/Critical_points_bmin%s_bmax%s.png" %(HOMEDIR, beta_low, beta_high))
plt.show()
# Out:
# [4.35701968 4.37521096 4.39218496 4.40852696 4.42485748 4.43980239
#  4.45390997 4.47056166 4.4860139  4.49771195 4.51091417 4.52463718
#  4.53848606 4.54773101 4.56337679 4.5728395  4.58688575 4.59725591
#  4.61072168 4.62149256 4.63165422 4.64229369 4.65376225 4.66401727
#  4.67222714 4.6842649  4.69128451 4.70230141 4.71138815 4.7205892
#  4.72984176 4.73925312]
# [8.48326875 8.51948081 8.55794952 8.59584637 8.63019044 8.66389287
#  8.6941087  8.72277783 8.75660723 8.78521435 8.81172919 8.83613119
#  8.86213437 8.88879015 8.91632305 8.93856277 8.9597485  8.98202702
#  9.00175118 9.02580469 9.05024831 9.06877228 9.09136772 9.11561095
#  9.12791041 9.14947897 9.16522099 9.18576521 9.20255224 9.2217801
#  9.23800828 9.25378261]
# [0.42795174 0.42822449 0.42855586 0.4288755  0.429158   0.42943449
#  0.42973365 0.4300164  0.43024857 0.43047248 0.43069011 0.43093345
#  0.43109467 0.43132749 0.43154067 0.43173238 0.43191584 0.43211151
#  0.43228573 0.43249682 0.43261771 0.43276947 0.43292721 0.43310238
#  0.433243   0.43342875 0.43356231 0.43370475 0.43384798 0.43399202
#  0.43413726 0.43428476]
