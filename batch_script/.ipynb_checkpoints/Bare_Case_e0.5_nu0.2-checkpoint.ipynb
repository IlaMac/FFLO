# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sys
import os
import math
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf
import scipy.integrate as integrate
import random
import h5py
from scipy.optimize import fsolve
from scipy.optimize import bisect

plt.rc('text',usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{bm}')
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Computer Modern'
plt.rcParams['axes.linewidth']  = 3.0
plt.rcParams['axes.labelsize']  = 30
plt.rcParams.update({'font.size': 22})
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['xtick.major.size'] = 4
plt.rcParams['ytick.major.size'] = 4
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['legend.fontsize']  = 22
plt.rcParams['legend.frameon']  = True
plt.rcParams["legend.fancybox"] = True
plt.rcParams["legend.shadow"] = True
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["axes.facecolor"] = 'white'
plt.rcParams["axes.edgecolor"] = 'black'

plt.rcParams['figure.figsize'] = 8, 8

plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 0
plt.rcParams['ytick.minor.width'] = 0

################################################

e=0.5
h=5.4
nu=0.2
beta_low=0.208
beta_high=0.212

###############################################


color=iter(plt.cm.rainbow(np.linspace(0,1,6)))

HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s" %(e, nu))

L=np.array([8, 10,12])

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10,10))
fig.suptitle(r"$\nu=%s$" %nu)
ax1[0].set_ylabel(r"$U$")
ax2[0].set_ylabel(r"$L \Upsilon$")
ax1[1].set_ylabel(r"$L \rho$")
ax2[1].set_ylabel(r"$|\Psi_0|$")
ax2[1].set_xlabel(r"$\beta$")
ax1[0].set_yscale('linear')
ax2[0].set_yscale('linear')
ax2[0].set_xlabel(r"$\beta$")
ax1[0].set_xlim((beta_low, beta_high))
ax2[0].set_xlim((beta_low, beta_high))
ax1[0].grid()
ax2[0].grid()

for l in range(len(L)):
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(HOMEDIR, L[l], e,  h, nu, beta_low, beta_high))
    file_Js_sum=("%s/Helicity_modulus_sum.txt" %(BASEDIR))
    beta, Js_sum, Js_sum_err= np.loadtxt(file_Js_sum, usecols=(0,1,2), unpack=True)
    
    file_Binder=("%s/Binder_cumulant.txt" %(BASEDIR))
    data_U= np.loadtxt(file_Binder)
    beta=data_U[0,:]
    U=data_U[1,:]
    U_err=data_U[2,:]

    file_DS=("%s/Dual_Stiffness.txt" %(BASEDIR))
    data_DS= np.loadtxt(file_DS)
    beta=data_DS[0,:]
    DS=data_DS[1,:]
    DS_err=data_DS[2,:]
    
    file_Psi=("%s/Psi_Density.txt" %(BASEDIR))
    data_Psi= np.loadtxt(file_Psi)
    print(data_Psi[3,:])
    beta=data_Psi[0,:]
    Psi1=data_Psi[1,:]
    Psi1_err=data_Psi[2,:]
    Psi2=data_Psi[3,:]
    Psi2_err=data_Psi[4,:]   
    Psi2=data_Psi[5,:]
    Psi2_err=data_Psi[6,:]  
    
    ax1[0].errorbar(beta, U, yerr=U_err, fmt='o-', label="%d" %L[l])
    ax2[0].errorbar(beta, L[l]*Js_sum, yerr=L[l]*Js_sum_err, fmt='o-')
    ax1[1].errorbar(beta, L[l]*DS, yerr=DS_err, fmt='o-')
    ax2[1].errorbar(beta, Psi1, yerr=Psi1_err, fmt='o-')
    
    #ax1.legend(title="L", loc='best')
    lines = []
    labels = []
    for ax in fig.axes:
        axLine, axLabel = ax.get_legend_handles_labels()
        lines.extend(axLine)
        labels.extend(axLabel)

fig.tight_layout()
fig.subplots_adjust(bottom=0.2, top=0.92)
fig.legend(lines, labels, loc = 'lower center', title="L", ncol=len(L))    
fig.savefig("%s/Critical_points_bmin%s_bmax%s.png" %(HOMEDIR, beta_low, beta_high))
plt.show()
# Out:
# [0.40082911 0.40093658 0.40113139 0.40134914 0.40155361 0.40174992
#  0.40192407 0.40218468 0.4024192  0.40264959 0.40291631 0.40318039
#  0.40349439 0.40372762 0.40407979 0.40433854 0.40466333 0.40494578
#  0.40523784 0.40562304 0.40594372 0.40631852 0.40665839 0.40698933
#  0.40741817 0.40780948 0.40824959 0.40863196 0.4090144  0.40944042
#  0.40982724 0.41026515]
# [0.40010397 0.40028066 0.40044132 0.40059254 0.40074372 0.40096833
#  0.40117609 0.40138937 0.40161449 0.40185385 0.40208925 0.40237995
#  0.40264524 0.4028775  0.40321139 0.4034935  0.40380868 0.40417561
#  0.40455545 0.40491624 0.40528948 0.40566882 0.40609662 0.40653561
#  0.40697548 0.40730895 0.40780092 0.40824518 0.4086412  0.40909078
#  0.40952779 0.40997708]
# [0.39974104 0.3998991  0.40003117 0.40017576 0.40033519 0.4005143
#  0.40070122 0.40088734 0.40114033 0.40135646 0.40161361 0.4018503
#  0.40216916 0.40245388 0.40277665 0.40307784 0.40341794 0.40379554
#  0.40423133 0.40456487 0.40497997 0.4054177  0.4058393  0.40625574
#  0.40670236 0.40713212 0.40761521 0.40805513 0.40855606 0.40897853
#  0.40945935 0.40989355]

# %%
################################################

e=0.5
h=5.4
nu=0.2
beta_low=0.2175
beta_high=0.2195

###############################################


color=iter(plt.cm.rainbow(np.linspace(0,1,6)))

HOMEDIR=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/e_%s/nu_%s" %(e, nu))

L=np.array([8, 10,12, 16])

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10,10))
fig.suptitle(r"$\nu=%s$" %nu)
ax1[0].set_ylabel(r"$U$")
ax2[0].set_ylabel(r"$L \Upsilon$")
ax1[1].set_ylabel(r"$L \rho$")
ax2[1].set_ylabel(r"$|\Psi_0|$")
ax2[1].set_xlabel(r"$\beta$")
ax1[0].set_yscale('linear')
ax2[0].set_yscale('linear')
ax2[0].set_xlabel(r"$\beta$")
ax1[0].grid()
ax2[0].grid()

for l in range(len(L)):
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(HOMEDIR, L[l], e,  h, nu, beta_low, beta_high))
    file_Js_sum=("%s/Helicity_modulus_sum.txt" %(BASEDIR))
    beta, Js_sum, Js_sum_err= np.loadtxt(file_Js_sum, usecols=(0,1,2), unpack=True)
    
    file_Binder=("%s/Binder_cumulant.txt" %(BASEDIR))
    data_U= np.loadtxt(file_Binder)
    beta=data_U[0,:]
    U=data_U[1,:]
    U_err=data_U[2,:]

    file_DS=("%s/Dual_Stiffness.txt" %(BASEDIR))
    data_DS= np.loadtxt(file_DS)
    beta=data_DS[0,:]
    DS=data_DS[1,:]
    DS_err=data_DS[2,:]
    
    file_Psi=("%s/Psi_Density.txt" %(BASEDIR))
    data_Psi= np.loadtxt(file_Psi)
    print(data_Psi[3,:])
    beta=data_Psi[0,:]
    Psi1=data_Psi[1,:]
    Psi1_err=data_Psi[2,:]
    Psi2=data_Psi[3,:]
    Psi2_err=data_Psi[4,:]   
    Psi2=data_Psi[5,:]
    Psi2_err=data_Psi[6,:]  
    
    ax1[0].errorbar(beta, U, yerr=U_err, fmt='o-', label="%d" %L[l])
    ax2[0].errorbar(beta, L[l]*Js_sum, yerr=L[l]*Js_sum_err, fmt='o-')
    ax1[1].errorbar(beta, L[l]*DS, yerr=L[l]*DS_err, fmt='o-')
    ax2[1].errorbar(beta, Psi1, yerr=Psi1_err, fmt='o-')
    
    #ax1.legend(title="L", loc='best')
    lines = []
    labels = []
    for ax in fig.axes:
        axLine, axLabel = ax.get_legend_handles_labels()
        lines.extend(axLine)
        labels.extend(axLabel)

fig.tight_layout()
fig.subplots_adjust(bottom=0.2, top=0.92)
fig.legend(lines, labels, loc = 'lower center', title="L", ncol=len(L))    
fig.savefig("%s/Critical_points_bmin%s_bmax%s.png" %(HOMEDIR, beta_low, beta_high))
plt.show()
# Out:
# [0.42746482 0.42756736 0.42774145 0.42792326 0.4281165  0.42820817
#  0.42839587 0.42852248 0.4286327  0.42875603 0.4289132  0.42908943
#  0.42920402 0.42930376 0.42938736 0.42950819 0.42966038 0.42976758
#  0.42989706 0.42998085 0.43013639 0.43018979 0.43030623 0.43043708
#  0.43059705 0.43069317 0.43084279 0.43091466 0.43099975 0.43113008
#  0.43123334 0.43128958]
# [0.42721484 0.42740989 0.42756226 0.42774617 0.42791186 0.42807279
#  0.42821354 0.42834619 0.4285192  0.42867024 0.42880162 0.42892981
#  0.42908138 0.4292194  0.42932776 0.42945585 0.4296128  0.42971096
#  0.42981449 0.42998436 0.43010305 0.43023044 0.43032836 0.43045857
#  0.43056065 0.43072148 0.43081318 0.43093604 0.43101595 0.43115138
#  0.43125893 0.43137096]
# [0.4270225  0.42719349 0.42739992 0.42754504 0.42774179 0.42788819
#  0.42805617 0.42822623 0.42838309 0.42854127 0.42866885 0.42885674
#  0.42897742 0.42912716 0.42930099 0.42941623 0.42959213 0.42973704
#  0.42982365 0.42999436 0.43007559 0.43021351 0.43035064 0.43045575
#  0.43060361 0.43068021 0.43079337 0.43091521 0.43101959 0.43111933
#  0.43124381 0.43136475]
# [0.42667731 0.42686974 0.42708801 0.42725508 0.42746231 0.42765588
#  0.42785634 0.42805053 0.42821419 0.42841333 0.4285852  0.42875042
#  0.42889026 0.42904387 0.42921695 0.42935782 0.4294941  0.42964103
#  0.42976694 0.42992903 0.43005308 0.43016638 0.43031071 0.43044542
#  0.43054596 0.43069545 0.43079741 0.43092953 0.43104726 0.43114189
#  0.43123268 0.43133723]
