# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sys
import os
import math
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf
import scipy.integrate as integrate
import random
import h5py
from scipy.optimize import fsolve
from scipy.optimize import bisect


plt.rc('text',usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{bm}')
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Computer Modern'
plt.rcParams['axes.linewidth']  = 3.0
plt.rcParams['axes.labelsize']  = 30
plt.rcParams.update({'font.size': 22})
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 25
plt.rcParams['xtick.major.size'] = 4
plt.rcParams['ytick.major.size'] = 4
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['legend.fontsize']  = 22
plt.rcParams['legend.frameon']  = False
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.shadow"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["axes.facecolor"] = 'white'
plt.rcParams["axes.edgecolor"] = 'black'

plt.rcParams['figure.figsize'] = 8, 8

plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 0
plt.rcParams['ytick.minor.width'] = 0

################################################

e=0.5
h=5.4

nu=np.array([0, 0.1, 0.2])

###############################################

################ U(1) transition ##################

betac_u1=np.zeros((len(nu)))
err_betac_u1=np.zeros((len(nu)))

###############################################
#                                             #
#                 nu=0;                       #
#                                             #
###############################################

n=0
beta_low=0.2245
beta_high=0.229
nbeta=64
L=np.array([8,10,12])


if( (nu[n]).is_integer()): nu_n=int(nu[n])

folder_out=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/nu_%s/e_%s/h_%s" %(nu_n, e, h))

fig, ax1 = plt.subplots(nrows=1, figsize=(6,6))
ax1.set_title(r"$h=%s$; $e=%s$; $\nu=%s$" %(h, e, nu[n]))
ax1.set_xlabel(r"$\beta$")
ax1.set_ylabel(r"$L\rho$")

color=iter(plt.cm.rainbow(np.linspace(0,1,len(L)+1)))

Ds_pol=[]

for l in range(len(L)):
    c_m=next(color)
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(folder_out, L[l], e,  h, nu_n, beta_low, beta_high))
    data_Ds= np.loadtxt("%s/Dual_Stiffness.txt" %(BASEDIR))
    beta= data_Ds[0]
    Ds_mean= data_Ds[1]
    Ds_err= data_Ds[2] 
    Ds_pol.append(np.poly1d(np.polyfit(beta, Ds_mean, 3)))
    ax1.plot(beta, Ds_pol[l](beta), '-', c=c_m)
    ax1.errorbar(beta, Ds_mean, yerr=Ds_err, capsize=2, c=c_m, label="L=%s" %L[l])

ax1.legend(loc="best")
plt.tight_layout()
plt.show()
    
betac_cross=[]
a=beta[0]
b=beta[-1]
print(a,b)
for l1 in range(len(L)):
    for l2 in range(l1+1, len(L)):
        Diff = Ds_pol[l1] -  Ds_pol[l2]
        #Return the roots of the (non-linear) equations defined by func(x) = 0 given a starting estimate
        #betac_cross.append(bisect(Diff, beta[0], beta[-1]))
        betac_cross.append(fsolve(Diff,0.228))
   
betac_u1[n]=np.mean(betac_cross)
err_betac_u1[n]=np.sqrt(np.var(betac_cross)/(len(betac_cross)-1))

###############################################
#                                             #
#                 nu=0.1;                       #
#                                             #
###############################################

n=1
beta_low=0.222
beta_high=0.225
nbeta=32
L=np.array([8,10,12, 16,20])

nu_n=nu[n]
if( (nu[n]).is_integer()): nu_n=int(nu[n])

folder_out=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/nu_%s/e_%s" %(nu_n, e))

fig, ax1 = plt.subplots(nrows=1, figsize=(6,6))
ax1.set_title(r"$h=%s$; $e=%s$; $\nu=%s$" %(h, e, nu[n]))
ax1.set_xlabel(r"$\beta$")
ax1.set_ylabel(r"$L\rho$")

color=iter(plt.cm.rainbow(np.linspace(0,1,len(L)+1)))

Ds_pol=[]

for l in range(len(L)):
    c_m=next(color)
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(folder_out, L[l], e,  h, nu_n, beta_low, beta_high))
    data_Ds= np.loadtxt("%s/Dual_Stiffness.txt" %(BASEDIR))
    beta= data_Ds[0]
    Ds_mean= data_Ds[1]
    Ds_err= data_Ds[2] 
    Ds_pol.append(np.poly1d(np.polyfit(beta, Ds_mean, 3 )))
    ax1.plot(beta, Ds_pol[l](beta), '-', c=c_m)
    ax1.errorbar(beta, Ds_mean, yerr=Ds_err, capsize=2, c=c_m, label="L=%s" %L[l])

ax1.legend(loc="best")
plt.tight_layout()
plt.show()
    
betac_cross=[]
for l1 in range(len(L)):
    for l2 in range(l1+1, len(L)):
        Diff = Ds_pol[l1] -  Ds_pol[l2]
        #Return the roots of the (non-linear) equations defined by func(x) = 0 given a starting estimate
        betac_cross.append(bisect(Diff, beta[0], beta[-1]))
        
betac_u1[n]=np.mean(betac_cross)
err_betac_u1[n]=np.sqrt(np.var(betac_cross)/(len(betac_cross)-1))



###############################################
#                                             #
#                 nu=0.2;                       #
#                                             #
###############################################

n=2
beta_low=0.2175
beta_high=0.2195
nbeta=32
L=np.array([8,10,12, 16,20])

nu_n=nu[n]
if( (nu[n]).is_integer()): nu_n=int(nu[n])

folder_out=("/Users/ilaria/Desktop/MultiComponents_SC/Output_3C/nu_%s/e_%s" %(nu_n, e))

fig, ax1 = plt.subplots(nrows=1, figsize=(6,6))
ax1.set_title(r"$h=%s$; $e=%s$; $\nu=%s$" %(h, e, nu[n]))
ax1.set_xlabel(r"$\beta$")
ax1.set_ylabel(r"$L\rho$")

color=iter(plt.cm.rainbow(np.linspace(0,1,len(L)+1)))

Ds_pol=[]

for l in range(len(L)):
    c_m=next(color)
    BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(folder_out, L[l], e,  h, nu_n, beta_low, beta_high))
    data_Ds= np.loadtxt("%s/Dual_Stiffness.txt" %(BASEDIR))
    beta= data_Ds[0]
    Ds_mean= data_Ds[1]
    Ds_err= data_Ds[2] 
    Ds_pol.append(np.poly1d(np.polyfit(beta, Ds_mean, 3 )))
    ax1.plot(beta, Ds_pol[l](beta), '-', c=c_m)
    ax1.errorbar(beta, Ds_mean, yerr=Ds_err, capsize=2, c=c_m, label="L=%s" %L[l])

ax1.legend(loc="best")
plt.tight_layout()
plt.show()

betac_cross=[]
for l1 in range(len(L)):
    for l2 in range(l1+1, len(L)):
        Diff = Ds_pol[l1] -  Ds_pol[l2]
        #Return the roots of the (non-linear) equations defined by func(x) = 0 given a starting estimate
        betac_cross.append(bisect(Diff, beta[0], beta[-1]))
        
betac_u1[n]=np.mean(betac_cross)
err_betac_u1[n]=np.sqrt(np.var(betac_cross)/(len(betac_cross)-1))

print(betac_u1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-ec0b7032eb02> in <module>
#      86     c_m=next(color)
#      87     BASEDIR=("%s/L%d_a0_b1_eta1_e%s_h%s_nu%s_bmin%s_bmax%s"  %(folder_out, L[l], e,  h, nu_n, beta_low, beta_high))
# ---> 88     data_Ds= np.loadtxt("%s/Dual_Stiffness.txt" %(BASEDIR))
#      89     beta= data_Ds[0]
#      90     Ds_mean= data_Ds[1]
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: /Users/ilaria/Desktop/MultiComponents_SC/Output_3C/nu_0/e_0.5/h_5.4/L8_a0_b1_eta1_e0.5_h5.4_nu0_bmin0.2245_bmax0.229/Dual_Stiffness.txt not found.

# %%
fig, ax1 = plt.subplots(nrows=1, figsize=(6,6))
ax1.set_title(r"$h=%s$; $e=%s$" %(h, e))
ax1.set_xlabel(r"$\nu$")
ax1.set_ylabel(r"$\beta_c(U(1))$")
ax1.plot(nu, betac_u1, 'o-', c='red')
ax1.errorbar(nu, betac_u1, yerr=err_betac_u1, fmt='o', c='red')
plt.tight_layout()
plt.show()
